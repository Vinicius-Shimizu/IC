# %%
from sppl.compilers.ast_to_spe import Id
from sppl.compilers.ast_to_spe import IfElse
from sppl.compilers.ast_to_spe import Otherwise
from sppl.compilers.ast_to_spe import Sample
from sppl.compilers.ast_to_spe import IdArray
from sppl.compilers.ast_to_spe import For
from sppl.compilers.ast_to_spe import Sequence
from sppl.compilers.ast_to_spe import Transform
from sppl.distributions import bernoulli
from sppl.distributions import randint
from sppl.sym_util import binspace
from sppl.math_util import allclose

import numpy as np

# %%
# %load_ext sppl.magics

# %%
# %%sppl model
# # p1 ~= 0.15
# # p2 ~= 0.15
# # p3 ~= 0.10
# # p4 ~= 0.10
# # p5 ~= 0.10
# # p6 ~= 0.10
# # p7 ~= 0.05
# # p8 ~= 0.20
# # p9 ~= 0.05
#
# p1 = rvdiscrete("p1", [0.15, 0.85])
# # dice1 ~= choice({"1": p1, "2": p2, "3": p3, "4": p4, "5": p5, "6": p6, "7": p7, "8": p8, "9": p9})
# # dice2 ~= choice({"1": p1, "2": p2, "3": p3, "4": p4, "5": p5, "6": p6, "7": p7, "8": p8, "9": p9})
# # dice2 ~= choice({"1": p1_1, "2": p1_1, "3": p1_1, "4": p1_1, "5": p1_1, "6": p1_2, "7": p1_2, "8": p1_2, "9": p1_2})
# # if (dice1 == '1'):
# #     if (dice2 == '1'):
# #         Sum ~= atomic(loc=2)
# #     elif (dice2 == '2'):
# #         Sum ~= atomic(loc=3)
# #     elif (dice2 == '3'):
# #         Sum ~= atomic(loc=4)
# #     elif (dice2 == '4'):
# #         Sum ~= atomic(loc=5)
# #     elif (dice2 == '5'):
# #         Sum ~= atomic(loc=6)
# #     elif (dice2 == '6'):
# #         Sum ~= atomic(loc=7)
# #     elif (dice2 == '7'):
# #         Sum ~= atomic(loc=8)
# #     elif (dice2 == '8'):
# #         Sum ~= atomic(loc=9)
# #     else:
# #         Sum ~= atomic(loc=10)
# # elif (dice1 == '2'):
# #     if (dice2 == '1'):
# #         Sum ~= atomic(loc=3)
# #     elif (dice2 == '2'):
# #         Sum ~= atomic(loc=4)
# #     elif (dice2 == '3'):
# #         Sum ~= atomic(loc=5)
# #     elif (dice2 == '4'):
# #         Sum ~= atomic(loc=6)
# #     elif (dice2 == '5'):
# #         Sum ~= atomic(loc=7)
# #     elif (dice2 == '6'):
# #         Sum ~= atomic(loc=8)
# #     elif (dice2 == '7'):
# #         Sum ~= atomic(loc=9)
# #     elif (dice2 == '8'):
# #         Sum ~= atomic(loc=10)
# #     else:
# #         Sum ~= atomic(loc=11)
# # elif (dice1 == '3'):
# #     if (dice2 == '1'):
# #         Sum ~= atomic(loc=4)
# #     elif (dice2 == '2'):
# #         Sum ~= atomic(loc=5)
# #     elif (dice2 == '3'):
# #         Sum ~= atomic(loc=6)
# #     elif (dice2 == '4'):
# #         Sum ~= atomic(loc=7)
# #     elif (dice2 == '5'):
# #         Sum ~= atomic(loc=8)
# #     elif (dice2 == '6'):
# #         Sum ~= atomic(loc=9)
# #     elif (dice2 == '7'):
# #         Sum ~= atomic(loc=10)
# #     elif (dice2 == '8'):
# #         Sum ~= atomic(loc=11)
# #     else:
# #         Sum ~= atomic(loc=12)
# # elif (dice1 == '4'):
# #     if (dice2 == '1'):
# #         Sum ~= atomic(loc=5)
# #     elif (dice2 == '2'):
# #         Sum ~= atomic(loc=6)
# #     elif (dice2 == '3'):
# #         Sum ~= atomic(loc=7)
# #     elif (dice2 == '4'):
# #         Sum ~= atomic(loc=8)
# #     elif (dice2 == '5'):
# #         Sum ~= atomic(loc=9)
# #     elif (dice2 == '6'):
# #         Sum ~= atomic(loc=10)
# #     elif (dice2 == '7'):
# #         Sum ~= atomic(loc=11)
# #     elif (dice2 == '8'):
# #         Sum ~= atomic(loc=12)
# #     else:
# #         Sum ~= atomic(loc=13)
# # elif (dice1 == '5'):
# #     if (dice2 == '1'):
# #         Sum ~= atomic(loc=6)
# #     elif (dice2 == '2'):
# #         Sum ~= atomic(loc=7)
# #     elif (dice2 == '3'):
# #         Sum ~= atomic(loc=8)
# #     elif (dice2 == '4'):
# #         Sum ~= atomic(loc=9)
# #     elif (dice2 == '5'):
# #         Sum ~= atomic(loc=10)
# #     elif (dice2 == '6'):
# #         Sum ~= atomic(loc=11)
# #     elif (dice2 == '7'):
# #         Sum ~= atomic(loc=12)
# #     elif (dice2 == '8'):
# #         Sum ~= atomic(loc=13)
# #     else:
# #         Sum ~= atomic(loc=14)
# # elif (dice1 == '6'):
# #     if (dice2 == '1'):
# #         Sum ~= atomic(loc=7)
# #     elif (dice2 == '2'):
# #         Sum ~= atomic(loc=8)
# #     elif (dice2 == '3'):
# #         Sum ~= atomic(loc=9)
# #     elif (dice2 == '4'):
# #         Sum ~= atomic(loc=10)
# #     elif (dice2 == '5'):
# #         Sum ~= atomic(loc=11)
# #     elif (dice2 == '6'):
# #         Sum ~= atomic(loc=12)
# #     elif (dice2 == '7'):
# #         Sum ~= atomic(loc=13)
# #     elif (dice2 == '8'):
# #         Sum ~= atomic(loc=14)
# #     else:
# #         Sum ~= atomic(loc=15)
# # elif (dice1 == '7'):
# #     if (dice2 == '1'):
# #         Sum ~= atomic(loc=8)
# #     elif (dice2 == '2'):
# #         Sum ~= atomic(loc=9)
# #     elif (dice2 == '3'):
# #         Sum ~= atomic(loc=10)
# #     elif (dice2 == '4'):
# #         Sum ~= atomic(loc=11)
# #     elif (dice2 == '5'):
# #         Sum ~= atomic(loc=12)
# #     elif (dice2 == '6'):
# #         Sum ~= atomic(loc=13)
# #     elif (dice2 == '7'):
# #         Sum ~= atomic(loc=14)
# #     elif (dice2 == '8'):
# #         Sum ~= atomic(loc=15)
# #     else:
# #         Sum ~= atomic(loc=16)
# # elif (dice1 == '8'):
# #     if (dice2 == '1'):
# #         Sum ~= atomic(loc=9)
# #     elif (dice2 == '2'):
# #         Sum ~= atomic(loc=10)
# #     elif (dice2 == '3'):
# #         Sum ~= atomic(loc=11)
# #     elif (dice2 == '4'):
# #         Sum ~= atomic(loc=12)
# #     elif (dice2 == '5'):
# #         Sum ~= atomic(loc=13)
# #     elif (dice2 == '6'):
# #         Sum ~= atomic(loc=14)
# #     elif (dice2 == '7'):
# #         Sum ~= atomic(loc=15)
# #     elif (dice2 == '8'):
# #         Sum ~= atomic(loc=16)
# #     else:
# #         Sum ~= atomic(loc=17)
# # else:
# #     if (dice2 == '1'):
# #         Sum ~= atomic(loc=10)
# #     elif (dice2 == '2'):
# #         Sum ~= atomic(loc=11)
# #     elif (dice2 == '3'):
# #         Sum ~= atomic(loc=12)
# #     elif (dice2 == '4'):
# #         Sum ~= atomic(loc=13)
# #     elif (dice2 == '5'):
# #         Sum ~= atomic(loc=14)
# #     elif (dice2 == '6'):
# #         Sum ~= atomic(loc=15)
# #     elif (dice2 == '7'):
# #         Sum ~= atomic(loc=16)
# #     elif (dice2 == '8'):
# #         Sum ~= atomic(loc=17)
# #     else:
# #         Sum ~= atomic(loc=18)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28605/4167680712.py in <module>
# ...

# %%
# %sppl_to_graph model

# %%
n = %sppl_get_namespace model
# print(n.model.prob(n.Sum << {2}))

# p1 ~= 0.15
# p2 ~= 0.15
# p3 ~= 0.10
# p4 ~= 0.10 
# p5 ~= 0.10 
# p6 ~= 0.10 
# p7 ~= 0.05 
# p8 ~= 0.20
# p9 ~= 0.05




# event = (n.dice1 << {'1'} | n.dice2 << {'1'})
# model_condition = n.model.condition(event)
# print(model_condition.prob(n.Sum << {2}))
# model_condition = n.model.condition(n.p1_1 << {2})
# model_condition = n.model.condition((0 < n.Sum) < 19)
# print(model_condition.prob(n.Sum << {2}))

# %%
# %sppl_to_graph model_condition

# %%
prob_dist1 = np.array([0.05, 0.10, 0.15, 0.10, 0.10, 0.10, 0.10, 0.10, 0.10, 0.10])
prob_dist2 = np.array([0.05, 0.10, 0.15, 0.10, 0.10, 0.10, 0.10, 0.10, 0.10, 0.10])

# digit1_1 = n.model.condition(n.dice1 << {'1'})
# digit2_1 = n.model.condition(n.dice2 << {'1'})

# %%
# %sppl_to_graph modelc
